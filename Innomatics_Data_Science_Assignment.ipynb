# %% [markdown]
# # Innomatics

# %% [markdown]
# ## Importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df_movies = pd.read_csv('~/Downloads/movie_data/movies.csv')
df.shape
df_ratings = pd.read_csv('~/Downloads/movie_data/ratings.csv')
df.shape
# Out:
# (100836, 4)

# %%
df_ratings.userId.unique().shape
# Out:
# (610,)

# %%
df_merged = df_ratings.merge(df_movies, on='movieId', how='inner')
df_merged
# Out:
#         userId  movieId  rating   timestamp                             title  \
# 0            1        1     4.0   964982703                  Toy Story (1995)
# 1            5        1     4.0   847434962                  Toy Story (1995)
# 2            7        1     4.5  1106635946                  Toy Story (1995)
# 3           15        1     2.5  1510577970                  Toy Story (1995)
# 4           17        1     4.5  1305696483                  Toy Story (1995)
# ...        ...      ...     ...         ...                               ...
# 100831     610   160341     2.5  1479545749                  Bloodmoon (1997)
# 100832     610   160527     4.5  1479544998  Sympathy for the Underdog (1971)
# 100833     610   160836     3.0  1493844794                     Hazard (2005)
# 100834     610   163937     3.5  1493848789                Blair Witch (2016)
# 100835     610   163981     3.5  1493850155                         31 (2016)
#
# ...

# %%
df_merged.groupby('movieId').userId.count().reset_index().sort_values('userId',ascending=False)
# Out:
#       movieId  userId
# 314       356     329
# 277       318     317
# 257       296     307
# 510       593     279
# 1938     2571     278
# ...       ...     ...
# 3053     4093       1
# 3049     4089       1
# 6687    58351       1
# 3045     4083       1
# 9723   193609       1
#
# [9724 rows x 2 columns]

# %%
df_merged[df_merged.movieId==356]
# Out:
#       userId  movieId  rating   timestamp                title  \
# 2426       1      356     4.0   964980962  Forrest Gump (1994)
# 2427       6      356     5.0   845553200  Forrest Gump (1994)
# 2428       7      356     5.0  1106635915  Forrest Gump (1994)
# 2429       8      356     3.0   839463527  Forrest Gump (1994)
# 2430      10      356     3.5  1455301685  Forrest Gump (1994)
# ...      ...      ...     ...         ...                  ...
# 2750     605      356     3.0  1277097509  Forrest Gump (1994)
# 2751     606      356     4.0  1171231370  Forrest Gump (1994)
# 2752     608      356     3.0  1117162603  Forrest Gump (1994)
# 2753     609      356     4.0   847220869  Forrest Gump (1994)
# 2754     610      356     3.0  1493844769  Forrest Gump (1994)
#
#                         genres
# 2426  Comedy|Drama|Romance|War
# 2427  Comedy|Drama|Romance|War
# 2428  Comedy|Drama|Romance|War
# 2429  Comedy|Drama|Romance|War
# 2430  Comedy|Drama|Romance|War
# ...

# %%
df_tags = pd.read_csv('~/Downloads/movie_data/tags.csv')

# %%
df_tags_movies = df_tags.merge(df_movies, on='movieId', how='inner')
df_tags_movies
# Out:
#       userId  movieId               tag   timestamp  \
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3         62    60756            comedy  1528934384
# 4         62    60756             funny  1528934381
# ...      ...      ...               ...         ...
# 3678     606     5694              70mm  1175638092
# 3679     606     6107      World War II  1178473747
# 3680     606     7936           austere  1173392334
# 3681     610     3265            gun fu  1493843984
# 3682     610     3265  heroic bloodshed  1493843978
#
#                                                   title  \
# 0                                  Step Brothers (2008)
# 1                                  Step Brothers (2008)
# 2                                  Step Brothers (2008)
# 3                                  Step Brothers (2008)
# ...

# %%
df_tags_movies[df_tags_movies.title == 'Matrix, The (1999)']
# Out:
#       userId  movieId                 tag   timestamp               title  \
# 1270     424     2571        martial arts  1457842912  Matrix, The (1999)
# 1271     424     2571              sci-fi  1457842899  Matrix, The (1999)
# 1272     474     2571  alternate universe  1137204991  Matrix, The (1999)
# 1273     537     2571          philosophy  1424141098  Matrix, The (1999)
# 1274     537     2571    post apocalyptic  1424141101  Matrix, The (1999)
#
#                       genres
# 1270  Action|Sci-Fi|Thriller
# 1271  Action|Sci-Fi|Thriller
# 1272  Action|Sci-Fi|Thriller
# 1273  Action|Sci-Fi|Thriller
# 1274  Action|Sci-Fi|Thriller

# %%
df_judgementday = df_merged[df_merged.title=="Terminator 2: Judgment Day (1991)"]
print(np.mean(df_judgementday['rating']))
# Out:
# 3.970982142857143

# %%
df_fightclub = df_merged[df_merged.title=="Fight Club (1999)"]
df_fightclub
# Out:
#        userId  movieId  rating   timestamp              title  \
# 14323       1     2959     5.0   964983282  Fight Club (1999)
# 14324       4     2959     2.0   945078528  Fight Club (1999)
# 14325      10     2959     0.5  1455356582  Fight Club (1999)
# 14326      15     2959     2.5  1510571747  Fight Club (1999)
# 14327      16     2959     3.5  1377476874  Fight Club (1999)
# ...       ...      ...     ...         ...                ...
# 14536     601     2959     5.0  1441639461  Fight Club (1999)
# 14537     603     2959     4.0   963176105  Fight Club (1999)
# 14538     606     2959     5.0  1171231517  Fight Club (1999)
# 14539     608     2959     5.0  1117336631  Fight Club (1999)
# 14540     610     2959     5.0  1479541966  Fight Club (1999)
#
#                             genres
# 14323  Action|Crime|Drama|Thriller
# 14324  Action|Crime|Drama|Thriller
# 14325  Action|Crime|Drama|Thriller
# 14326  Action|Crime|Drama|Thriller
# 14327  Action|Crime|Drama|Thriller
# ...

# %%
sns.kdeplot(x='rating', data=df_fightclub)
plt.show()

# %%
df_ratingmovies = df_ratings.merge(df_movies, on='movieId', how='inner')
df_ratingmovies
# Out:
#         userId  movieId  rating   timestamp                             title  \
# 0            1        1     4.0   964982703                  Toy Story (1995)
# 1            5        1     4.0   847434962                  Toy Story (1995)
# 2            7        1     4.5  1106635946                  Toy Story (1995)
# 3           15        1     2.5  1510577970                  Toy Story (1995)
# 4           17        1     4.5  1305696483                  Toy Story (1995)
# ...        ...      ...     ...         ...                               ...
# 100831     610   160341     2.5  1479545749                  Bloodmoon (1997)
# 100832     610   160527     4.5  1479544998  Sympathy for the Underdog (1971)
# 100833     610   160836     3.0  1493844794                     Hazard (2005)
# 100834     610   163937     3.5  1493848789                Blair Witch (2016)
# 100835     610   163981     3.5  1493850155                         31 (2016)
#
# ...

# %%
user_movies = df_ratingmovies.groupby('movieId').agg({'rating':['count','mean']})
user_movies.columns = user_movies.columns.droplevel(0)

# %%
user_movies.reset_index(inplace=True)

# %%
user_movies.rename(columns = {'count':'count_rating','mean':'mean_rating'}, inplace=True)
user_movies
# Out:
#       movieId  count_rating  mean_rating
# 0           1           215     3.920930
# 1           2           110     3.431818
# 2           3            52     3.259615
# 3           4             7     2.357143
# 4           5            49     3.071429
# ...       ...           ...          ...
# 9719   193581             1     4.000000
# 9720   193583             1     3.500000
# 9721   193585             1     3.500000
# 9722   193587             1     3.500000
# 9723   193609             1     4.000000
#
# [9724 rows x 3 columns]

# %%
user_movies_more50 = user_movies[user_movies.count_rating >50]

# %%
user_movies_more50.sort_values('count_rating', ascending=False)[:10]
# Out:
#       movieId  count_rating  mean_rating
# 314       356           329     4.164134
# 277       318           317     4.429022
# 257       296           307     4.197068
# 510       593           279     4.161290
# 1938     2571           278     4.192446
# 224       260           251     4.231076
# 418       480           238     3.750000
# 97        110           237     4.031646
# 507       589           224     3.970982
# 461       527           220     4.225000

# %%
display(df_movies[df_movies.movieId == 260])
display(df_movies[df_movies.movieId == 480])
display(df_movies[df_movies.movieId == 110])
display(df_movies[df_movies.movieId == 589])
display(df_movies[df_movies.movieId == 527])
# Out:
#      movieId                                      title  \
# 224      260  Star Wars: Episode IV - A New Hope (1977)
#
#                       genres
# 224  Action|Adventure|Sci-Fi
#      movieId                 title                            genres
# 418      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
#     movieId              title            genres
# 97      110  Braveheart (1995)  Action|Drama|War
#      movieId                              title         genres
# 507      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi
#      movieId                    title     genres
# 461      527  Schindler's List (1993)  Drama|War

# %%
# links.csv
df_links = pd.read_csv('~/Downloads/movie_data/links.csv')
df_links
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
user_movies_more50.columns
df_movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
user_movies_more50 = user_movies_more50.merge(df_movies, on='movieId', how='inner')
user_movies_more50.shape
# Out:
# (436, 5)

# %%
df_more50_links = df_links.merge(user_movies_more50, on='movieId', how='inner')
df_more50_links.shape
# Out:
# (436, 7)

# %%
display(df_more50_links.sort_values('title', ascending=True).iloc[200:250])
# Out:
#      movieId   imdbId    tmdbId  count_rating  mean_rating  \
# 397    51255   425112    4638.0            61     4.000000
# 78       466   107144    9255.0            60     2.866667
# 422    76093   892769   10191.0            53     3.943396
# 198     1610    99810    1669.0            90     3.872222
# 405    56174   480249    6479.0            62     3.483871
# 371     8644   343818    2048.0            61     3.491803
# 333     5218   268380     425.0            85     3.688235
# 79       474   107206    9386.0            70     3.692857
# 424    79132  1375666   27205.0           143     4.066434
# 374     8961   317705    9806.0           125     3.836000
# 113      780   116629     602.0           202     3.445545
# 173     1291    97576      89.0           140     4.046429
# 229     2115    87469      87.0           108     3.638889
# 412    68157   361748   16869.0            88     4.136364
# 433   109487   816692  157336.0            73     3.993151
# ...

# %%
df_more50_links[df_more50]
# Out:
# Empty DataFrame
# Columns: [movieId, imdbId, tmdbId, count_rating, mean_rating, title, genres]
# Index: []

# %%
# scraping imdb reviews
import requests
import numpy as np
from bs4 import BeautifulSoup

def scrapper(imdbId):
    id = str(int(imdbId))
    n_zeroes = 7 - len(id)
    new_id = "0"*n_zeroes + id
    URL = f"https://www.imdb.com/title/tt{new_id}/"
    request_header = {'Content-Type': 'text/html; charset=UTF-8', 
                      'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0', 
                      'Accept-Encoding': 'gzip, deflate, br'}
    response = requests.get(URL, headers=request_header)
    soup = BeautifulSoup(response.text)
    imdb_rating = soup.find('span', attrs={'FILL_IN_THE_BLANK' : 'FILL_IN_THE_BLANK'})
    return imdb_rating.text if imdb_rating else np.nan

# %%
print(scrapper("111161"))
# Out:
# nan
